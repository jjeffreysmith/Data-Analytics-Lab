# %%
import urllib2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-846c1dbd158b> in <module>()
# ----> 1 import urllib2
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
import urllib

# %%
import pandas

# %%
psg="http://www.psgtech.edu/"
a=urllib.urlopen(psg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d7bc9be8f76e> in <module>()
#       1 psg="http://www.psgtech.edu/"
# ----> 2 a=urllib.urlopen(psg)
#
# AttributeError: module 'urllib' has no attribute 'urlopen'

# %%
import requests
from bs4 import BeautifulSoup
psg = "http://psgim.ac.in/category/psgim/faculty/"
a = requests.get(psg)
soup = BeautifulSoup(r.content, 'html5lib')
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c5f5072abee7> in <module>()
#       3 psg = "http://psgim.ac.in/category/psgim/faculty/"
#       4 a = requests.get(psg)
# ----> 5 soup = BeautifulSoup(r.content, 'html5lib')
#       6 print(soup.prettify())
#
# NameError: name 'r' is not defined

# %%
import requests
from bs4 import BeautifulSoup
psg = "http://psgim.ac.in/2017/01/full-time-faculty/"
a = requests.get(psg)
soup = BeautifulSoup(a.content, 'html5lib')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Faculty &amp; Staff | PSG
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="http://psgim.ac.in/xmlrpc.php" rel="pingback"/>
#   <meta content="Powered by ionMag WordPress Theme - wpion.com" name="generator"/>
#   <link href="http://psgim.ac.in/wp-content/uploads/2017/07/logo3.png" rel="icon" type="image/png"/>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="http://psgim.ac.in/feed/" rel="alternate" title="PSG » Feed" type="application/rss+xml"/>
#   <link href="http://psgim.ac.in/comments/feed/" rel="alternate" title="PSG » Comments Feed" type="application/rss+xml"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup
psg = "http://psgim.ac.in/2017/01/full-time-faculty/"
a = requests.get(psg)
soup = BeautifulSoup(a.content, 'html5lib')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Full-Time Faculty | PSG
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="http://psgim.ac.in/xmlrpc.php" rel="pingback"/>
#   <meta content="Powered by ionMag WordPress Theme - wpion.com" name="generator"/>
#   <meta content="http://psgim.ac.in/wp-content/uploads/2017/01/staff.jpg" property="og:image"/>
#   <link href="http://psgim.ac.in/wp-content/uploads/2017/07/logo3.png" rel="icon" type="image/png"/>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="http://psgim.ac.in/feed/" rel="alternate" title="PSG » Feed" type="application/rss+xml"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup
url='http://psgim.ac.in/2017/01/full-time-faculty/'
resp=requests.get(url)
if resp.status_code==200:
    soup=BeautifulSoup(resp.text,'html.parser')    
    l=soup.find("div",{"class":"wpb_wrapper"})
    for i in l.findAll("a"):
        str=i.text
        if "Dr" in str:
            print(str)
else:
    print("Error")
# Out:
# Dr Archana Krishnan
# Dr KRISHNAVENI R
# Dr MANJU P GEORGE
# Dr Nandagopal R
# Dr RAMKUMAR N
#  Dr Srigayathri Devi K
# Dr SRIVIDYA V
# Dr VIJAYA T G
