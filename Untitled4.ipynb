# %%
import urllib.request
import pandas
r=pandas.read_csv("Y:\DA LAB\MovieGenre.csv", encoding = 'ISO-8859-1')
poster_url=r.Poster
n=0
for i in poster_url:
    try:
        urllib.request.urlretrieve(i,"D:\DA lab\Movies\Movie No." + str(n) + ".jpg")
        n+=1
    except:
        print("No URL")
# Out:
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
# No URL
